# %%
# hello
# March 16, 2026
# Robert Lu
# DSI class 7, python class 4

# %%
test_dict = {1: "first",
             2: "second",
             3: "third",
             4: "fourth"}

# %%
test_dict[1]
# Out:
# 'first'

# %%
test_dict.get(5) # returns None

# %%
test_dict.get(1) # use .get method on a dictionary to get the value
# Out:
# 'first'

# %%
del test_dict[1] # removes a key/value pair

# %%
test_dict
# Out:
# {1: 'first', 2: 'second', 3: 'third', 4: 'fourth'}

# %%
test_dict.keys()
# Out:
# dict_keys([1, 2, 3, 4])

# %%
test_dict.values()
# Out:
# dict_values(['first', 'second', 'third', 'fourth'])

# %%
test_dict.items()
# items are key/value pairs
# can iterate through key/value pairs, extract values
# Out:
# dict_items([(1, 'first'), (2, 'second'), (3, 'third'), (4, 'fourth')])

# %%
lats = (1, 2, 3, 4, 5)
lons = (11, 12, 13, 14, 15)

for i, j in zip(lats, lons):
    print(i,j)
# Out:
# 1 11
# 2 12
# 3 13
# 4 14
# 5 15

# %%
import numpy as np

test1 = np.array([1,2,3,4,5])
test2 = np.array([11,12,13,14,15])

for i, j in zip(test1, test2):
    print(i,j)
# Out:
# 1 11
# 2 12
# 3 13
# 4 14
# 5 15
