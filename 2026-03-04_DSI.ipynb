# %% [markdown]
# DSI class 4, python 1
#
# March 4, 2026

# %%
5 + 6
# Out:
# 11

# %%
print("hello!")
# Out:
# hello!

# %%
property
# Out:
# property

# %%
- 5
# Out:
# -5

# %%
def c_to_f(degrees_c):

    return (9/5)*degrees_c + 32

# %%
c_to_f(100)
# Out:
# 212.0

# %%
test_word = "test"

# %%
def test_print(word):
    
    print(word+"global test_word")
    return

# %%
test_print("aaa")
# Out:
# aaaglobal test_word
