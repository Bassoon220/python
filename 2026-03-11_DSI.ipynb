# %%
test = list()

# %%
help(list)
# Out:
# Help on class list in module builtins:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...

# %%
test = [1,2,3,4,5]
test
# Out:
# [1, 2, 3, 4, 5]

# %%
test[3] = 100
test
# Out:
# [1, 2, 3, 100, 5]

# %%
# use list() to create an independent memory copy of a list
# because if you dont, then the values point to the same memory location
# and changing one will change the other

# %%
test
# Out:
# [1, 2, 3, 100, 5]

# %%
test.insert(1,1)

# %%
test
# Out:
# [1, 1, 2, 3, 100, 5]

# %%
test.insert(1,7)

# %%
test
# Out:
# [1, 7, 2, 3, 4, 5]
