# %%
# Class 5, python 2
# Robert Lu
# March 9, 2026

# %%
print ("Let's see if this works")
# Out:
# Let's see if this works

# %%
print ("")

# %%
# carriage return \r
# move cursor back to the beginning of the current line, then continue updating text

print ("hello world\rhi ")
# Out:
# hi lo world

# %%
name = "Robert Lu"
name
# Out:
# 'Robert Lu'

# %%
name[::-1]
# Out:
# 'uL treboR'

# %%
# string methods
"I am not yelling".upper()
# Out:
# 'I AM NOT YELLING'

# %%
"This is unusual".count("s")
# Out:
# 3

# %%
"file_name.csv".endswith(".csv")
# Out:
# True

# %%
"long file name with space.csv".replace(" ", "_")
# Out:
# 'long_file_name_with_space.csv'

# %%
# string formatting

first_name = "Robert"
last_name = "Lu"

print("Robert Lu's initials are {}. {}.".format("R", "L"))
print("Robert Lu's initials are {}. {}.".format(first_name[0], last_name[0]))
print(f"Robert Lu's initials are {first_name[0]}. {last_name[0]}.")
# Out:
# Robert Lu's initials are R. L.
# Robert Lu's initials are R. L.
# Robert Lu's initials are R. L.

# %%
# can ask for help with string method using str.method
help(str.endswith)
# Out:
# Help on method_descriptor:
#
# endswith(...)
#     S.endswith(suffix[, start[, end]]) -> bool
#
#     Return True if S ends with the specified suffix, False otherwise.
#     With optional start, test S beginning at that position.
#     With optional end, stop comparing S at that position.
#     suffix can also be a tuple of strings to try.

# %%
# takes use input as a string
age = input("How old are you?")

# %%
age
# Out:
# '29'

# %%
"True" and True
# "True", the string is non empty and python considers it true
# non empty strings are considered "Truthy"

# The and operator returns the last falsy falue (a value that's false)
# or the last truthy value if all values are true based on the conditions
# non empty strings are truthy
# Out:
# True

# %%
True and "hello"

# normally, only compare boolean values with logic operators
# Out:
# 'hello'

# %%
"" and False
# empty string is considered false, so and returns first falsy value, the empty string
# Out:
# ''

# %%
"a" and False
# Out:
# False

# %%
False and "a"
# Out:
# False
